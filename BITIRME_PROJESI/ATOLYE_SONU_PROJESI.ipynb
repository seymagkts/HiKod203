# %% [markdown]
# ### Sürdürülebilirlik (Sustainability)

# %% [markdown]
# CARBON EMISSION DATASET FEATURES:
#
# * 'Body Type': Vücut tipi (Body type)
#
# * 'Sex': Cinsiyet (Gender)
#
# * 'Diet': Diyet (Diet)
#
# * 'How Often Shower': Duş alma sıklığı (Frequency of showering)
#
# * 'Heating Energy Source': Konut ısıtma enerjisi (Residential heating energy)
#
# * 'Transport': Ulaşım tercihi (Transportation preference)
#
# * 'Vehicle Type': Araç yakıt tipi (Vehicle fuel type)
#
# * 'Social Activity': Sosyal etkinliklere katılma sıklığı (Frequency of participating in social activities)
#
# * 'Monthly Grocery Bill': Market alışverişine harcanan aylık tutar, dolar cinsinden (Monthly amount spent on groceries, in dollars)
#
# * 'Frequency of Traveling by Air': Son ayda uçak kullanma sıklığı (Frequency of using aircraft in the last month)
#
# * 'Vehicle Monthly Distance Km':  Aracın son ayda kat ettiği kilometre (The kilometers traveled by vehicle in the last month)
#
# * 'Waste Bag Size': Çöp torbasının boyutu (Size of the garbage bag)
#
# * 'Waste Bag Weekly Count': Son hafta içinde atılan çöp miktarı (The amount of garbage thrown away in the last week)
#
# * 'How Long TV PC Daily Hour': TV veya PC karşısında geçirilen günlük süre (Daily time spent in front of TV or PC)
#
# * 'How Many New Clothes Monthly': Aylık satın alınan kıyafet sayısıdır (Number of clothes purchased monthly)
#
# * 'How Long Internet Daily Hour': Günlük olarak internette geçirilen süre (Time spent on the Internet daily)
#
# * 'Energy efficiency': Enerji tasarruflu cihazlar satın almayı önemseyip önemsemediğiniz (Whether or not you care about purchasing energy efficient devices)
#
# * 'Recycling': Geri dönüştürdüğü atıklardır (The wastes it recycles)
#
# * 'Cooking_With': Yemek pişirmede kullanılan cihazlar (Devices used in cooking)
#
# * 'CarbonEmission':Bağımlı değişken, toplam karbon emisyonları, kg (Dependent variable, total carbon emissions)
#
# KAYNAK (SOURCE): https://www.kaggle.com/datasets/dumanmesut/individual-carbon-footprint-calculation

# %% [markdown]
# ****

# %% [markdown]
# ##### Bu veri setinin amacı, bireylerin karbon ayak izini hesaplamaktır. Veri seti, kişisel enerji tüketimi, seyahat alışkanlıkları, beslenme tercihleri gibi çeşitli faktörlere dayanarak bireylerin karbon salınımını analiz etmeye yardımcı olacak bilgiler içerir.

# %% [markdown]
# ****

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("CarbonEmission.csv") # veri seti okuma
df.head() # ilk 5 satır
# Out:
#     Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 0  overweight  female  pescatarian            daily                  coal
# 1       obese  female   vegetarian  less frequently           natural gas
# 2  overweight    male     omnivore  more frequently                  wood
# 3  overweight    male     omnivore      twice a day                  wood
# 4       obese  female   vegetarian            daily                  coal
#
#       Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 0        public          NaN           often                   230
# 1  walk/bicycle          NaN           often                   114
# 2       private       petrol           never                   138
# 3  walk/bicycle          NaN       sometimes                   157
# 4       private       diesel           often                   266
#
#   Frequency of Traveling by Air  Vehicle Monthly Distance Km Waste Bag Size  \
# ...

# %%
df.tail() # son 5 satır
# Out:
#         Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 9995        obese    male     omnivore      twice a day                  coal
# 9996       normal  female        vegan      twice a day                  coal
# 9997   overweight  female   vegetarian            daily           electricity
# 9998  underweight    male        vegan  more frequently                  coal
# 9999        obese    male  pescatarian      twice a day                  wood
#
#          Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 9995       private       hybrid       sometimes                   230
# 9996       private          lpg           never                   234
# 9997  walk/bicycle          NaN       sometimes                   298
# 9998       private       petrol           often                   179
# 9999       private     electric       sometimes                   115
#
#      Frequency of Traveling by Air  Vehicle Monthly Distance Km  \
# ...

# %%
def check_df(df):
    print(df.info()) # veri seti hakkında genel bilgi
    print("************************************")
    print(df.describe().T) # temel istatistiksel özet bilgi
    print("************************************")
    print(df.isnull().sum()) # bos deger kontrolu
    print("************************************")
    print(df.shape) # veri setinin boyutu
    print("************************************")
    print(df.size) # toplam veri sayısı
    print("************************************")
    print(df.nunique()) # değişkenler kaç adet eşsiz değere sahip
    print("************************************")

# %%
check_df(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Body Type                      10000 non-null  object
#  1   Sex                            10000 non-null  object
#  2   Diet                           10000 non-null  object
#  3   How Often Shower               10000 non-null  object
#  4   Heating Energy Source          10000 non-null  object
#  5   Transport                      10000 non-null  object
#  6   Vehicle Type                   3279 non-null   object
#  7   Social Activity                10000 non-null  object
#  8   Monthly Grocery Bill           10000 non-null  int64
#  9   Frequency of Traveling by Air  10000 non-null  object
#  10  Vehicle Monthly Distance Km    10000 non-null  int64
#  11  Waste Bag Size                 10000 non-null  object
# ...

# %%
df["Vehicle Type"].unique()  
# Vehicle Type sütunundaki eşsiz değerler
# Out:
# array([nan, 'petrol', 'diesel', 'hybrid', 'lpg', 'electric'], dtype=object)

# %%
df["Transport"].value_counts()  
# Vehicle Type sütunundaki 6721 adet boş değerin sebebi 
# yaya/bisikletli veya toplu taşıma kullananların olması, yani eksik değer değildir.
# Out:
# walk/bicycle    3427
# public          3294
# private         3279
# Name: Transport, dtype: int64

# %%
df["Vehicle Type"].fillna("NonePWB", inplace=True) 
# eksik değerlerin NonePWB değeri ile doldurması

# %%
df.isnull().sum()
# Out:
# Body Type                        0
# Sex                              0
# Diet                             0
# How Often Shower                 0
# Heating Energy Source            0
# Transport                        0
# Vehicle Type                     0
# Social Activity                  0
# Monthly Grocery Bill             0
# Frequency of Traveling by Air    0
# Vehicle Monthly Distance Km      0
# Waste Bag Size                   0
# Waste Bag Weekly Count           0
# How Long TV PC Daily Hour        0
# How Many New Clothes Monthly     0
# How Long Internet Daily Hour     0
# Energy efficiency                0
# Recycling                        0
# Cooking_With                     0
# CarbonEmission                   0
# dtype: int64

# %%
df.columns = ['Body_Type', 'Sex', 'Diet', 'How_Often_Shower', 'Heating_Energy_Source',
       'Transport', 'Vehicle_Type', 'Social_Activity', 'Monthly_Grocery_Bill',
       'Frequency_of_Traveling_byAir', 'Vehicle_Monthly_Distance_Km',
       'Waste_Bag_Size', 'Waste_Bag_Weekly_Count', 'How_Long_TV_PC_Daily_Hour',
       'How_Many_New_Clothes_Monthly', 'How_Long_Internet_Daily_Hour',
       'Energy_efficiency', 'Recycling', 'Cooking_With', 'Carbon_Emission']
# daha rahat çağırma yapabilmek için kolon adlarını güncelledim. tamamen öznel.

# %%
df.Body_Type.unique()
# Body Type sütununa ait eşsiz değerler
# Out:
# array(['overweight', 'obese', 'underweight', 'normal'], dtype=object)

# %%
df.Diet.unique()
# Diet sütununa ait eşsiz değerler
# Out:
# array(['pescatarian', 'vegetarian', 'omnivore', 'vegan'], dtype=object)

# %%
df.Sex.value_counts()
# Sex sütununa ait eşsiz değerler ve sayıları
# Out:
# female    5007
# male      4993
# Name: Sex, dtype: int64

# %%
df.How_Often_Shower.unique()
# How Often Shower sütununa ait eşsiz değerler
# Out:
# array(['daily', 'less frequently', 'more frequently', 'twice a day'],
#       dtype=object)

# %%
df.Heating_Energy_Source.unique()
# Heating Energy Source sütununa ait eşsiz değerler
# Out:
# array(['coal', 'natural gas', 'wood', 'electricity'], dtype=object)

# %%
df.Frequency_of_Traveling_byAir.unique()
# Frequency of Traveling byAir sütununa ait eşsiz değerler
# Out:
# array(['frequently', 'rarely', 'never', 'very frequently'], dtype=object)

# %%
df[(df.Carbon_Emission == max(df.Carbon_Emission)) | (df.Carbon_Emission == min(df.Carbon_Emission))]
# en yüksek ve en düşük karbon emisyonu değerine sahip sütunlar.
# Out:
#         Body_Type     Sex        Diet How_Often_Shower Heating_Energy_Source  \
# 2292  underweight  female  vegetarian      twice a day           electricity
# 9773        obese    male  vegetarian            daily                  coal
#
#          Transport Vehicle_Type Social_Activity  Monthly_Grocery_Bill  \
# 2292  walk/bicycle      NonePWB       sometimes                   251
# 9773       private       petrol           often                   210
#
#      Frequency_of_Traveling_byAir  Vehicle_Monthly_Distance_Km Waste_Bag_Size  \
# 2292                        never                           11         medium
# 9773              very frequently                         9791          large
#
#       Waste_Bag_Weekly_Count  How_Long_TV_PC_Daily_Hour  \
# 2292                       1                          2
# 9773                       6                         16
#
#       How_Many_New_Clothes_Monthly  How_Long_Internet_Daily_Hour  \
# ...

# %%
veh_car = df.groupby("Vehicle_Type")[["Carbon_Emission"]].mean().reset_index()

# %%
chart_ = sns.barplot(y = "Carbon_Emission", 
            x = "Vehicle_Type",
            data = veh_car,
            palette = "magma")
plt.xlabel("Araç yakıt türü")
plt.ylabel("Karbon emisyonu değerleri")
plt.title("Araç yakıt türüne göre karbon emisyon değeri")
chart_.set(xticklabels=["none","dizel",
                        "elektrik",
                        "hibrit","lpg","petrol"]) 
plt.show()

# %%
tra_car = df.groupby("Transport")[["Carbon_Emission"]].mean().reset_index()

# %%
chart = sns.barplot(y = "Carbon_Emission",
                    x = "Transport",
                    data = tra_car,
                    palette = "ocean")
plt.xlabel("Ulaşım tercihi")
plt.ylabel("Karbon emisyonu değerleri")
plt.title("Ulaşım tercihine göre karbon emisyon değeri")
chart.set(xticklabels=["özel araç","toplu taşıma","yaya/bisiklet"])
plt.show()

# %%
tra_typ_car = df.groupby(["Transport","Vehicle_Type"])[["Carbon_Emission"]].mean().reset_index()

# %%
chart = sns.barplot(y = "Carbon_Emission",
                    hue = "Transport",
                    x="Vehicle_Type",
                    data = tra_typ_car,
                    palette = "winter")
plt.xlabel("Yakıt türü")
plt.ylabel("Karbon emisyonu değerleri")
plt.title("Ulaşım tercihi ve yakıt türüne göre karbon emisyon değeri")
chart.set(xticklabels=["dizel","elektrik","hibrit","lpg","petrol","NonePWB"])
plt.legend(title="Ulaşım tercihi")
plt.show()

# %%
air_car = df.groupby(["Frequency_of_Traveling_byAir"])[["Carbon_Emission"]].mean().reset_index()

# %%
chart2 = sns.barplot(y = "Carbon_Emission",
                     x = "Frequency_of_Traveling_byAir",
                     data = air_car,
                     palette = "cividis")
plt.xlabel("Son ayda uçak kullanma sıklığı")
plt.ylabel("Karbon emisyonu değerleri")
plt.title("Son ayda uçak kullanma sıklığına göre karbon emisyon değeri")
chart2.set(xticklabels=["sık","asla","nadiren","çok sık"])
plt.show()

# %%
df.groupby("How_Often_Shower")[["Carbon_Emission"]].mean().reset_index()
# Dus alma sıklığına göre karbon emisyon değeri
# Out:
#   How_Often_Shower  Carbon_Emission
# 0            daily      2238.115868
# 1  less frequently      2246.844793
# 2  more frequently      2287.193390
# 3      twice a day      2305.014308

# %%
df.groupby("Sex")[["Carbon_Emission"]].mean().reset_index()
# cinsiyete göre karbon emisyon değeri
# Out:
#       Sex  Carbon_Emission
# 0  female      2102.597164
# 1    male      2436.164430

# %%
sns.boxplot(y="Carbon_Emission",x = "Sex",data=df)
plt.title("Cinsiyete göre karbon emisyon dağılımı")
plt.ylabel("Karbon Emisyon Değeri")
plt.xlabel("Cinsiyet")
plt.show()

# %%
df.groupby("Body_Type")[["Carbon_Emission"]].mean().reset_index()
# vücut tipine göre karbon emisyon değeri
# Out:
#      Body_Type  Carbon_Emission
# 0       normal      2140.509503
# 1        obese      2561.212000
# 2   overweight      2358.919984
# 3  underweight      2019.027165

# %%
df.groupby(["Heating_Energy_Source"])[["Carbon_Emission"]].mean().reset_index()
# konut ısınma enerji türüne göre karbon emisyonu değeri, kömür, elektrik, doğal gaz, odun
# Out:
#   Heating_Energy_Source  Carbon_Emission
# 0                  coal      2495.060246
# 1           electricity      2039.379702
# 2           natural gas      2248.124289
# 3                  wood      2296.815672

# %%
df.groupby(["Energy_efficiency"])[["Carbon_Emission"]].mean().reset_index()
# Enerji tasarruflu cihazlar satın almayı önemseyip önemsemediğine göre karbon emisyon değeri
# Out:
#   Energy_efficiency  Carbon_Emission
# 0                No      2286.656628
# 1         Sometimes      2269.151314
# 2               Yes      2252.135404

# %%
df.groupby(["Vehicle_Type"]).agg({"Carbon_Emission":"mean",
                                  "Vehicle_Monthly_Distance_Km" : "mean"}).reset_index()
# araç yakıt türüne göre aylık gidilen ortalama km ve karbon emisyon değeri
# Out:
#   Vehicle_Type  Carbon_Emission  Vehicle_Monthly_Distance_Km
# 0      NonePWB      1921.912513                   526.554233
# 1       diesel      3230.204180                  5113.220257
# 2     electric      1883.293592                  5071.758569
# 3       hybrid      2708.500000                  5074.624611
# 4          lpg      3352.063128                  5266.670014
# 5       petrol      3749.887172                  5044.106646

# %%
df.groupby(["Sex"])[["Carbon_Emission",
                    "Monthly_Grocery_Bill"]].mean().reset_index()
# cinsiyete göre aylık ortalama market alışverişi harcaması ve karbon emisyonu değeri
# Out:
#       Sex  Carbon_Emission  Monthly_Grocery_Bill
# 0  female      2102.597164            172.729978
# 1    male      2436.164430            175.023633

# %%
die_se_car = df.groupby(["Diet"])[["Carbon_Emission"]].mean().reset_index()

# %%
chart3 = sns.barplot(y = "Carbon_Emission", 
            x = "Diet",
            data = die_se_car,
            palette = "cubehelix")
plt.xlabel("Beslenme şekli")
plt.ylabel("Karbon emisyonu değerleri")
plt.title("Beslenme türüne göre karbon emisyon değeri")
chart3.set(xticklabels=["hepçil","pesketaryen","vegan","vejetaryen"])
plt.show()

# %%
sns.lineplot(data=df, x = "How_Many_New_Clothes_Monthly", y="Carbon_Emission")
plt.ylabel("Karbon Emisyon Değeri")
plt.xlabel("Aylık satın alınan kıyafet sayısı")
plt.title("Aylık satın alınan kıyafet sayısına göre karbon emisyon değeri")
plt.show()

# %%
sns.histplot(data = df, x="Carbon_Emission")
plt.xlabel("Karbon Emisyon değeri")
plt.ylabel("Frekans")
plt.title("Karbon emisyon bağımlı değişkeninin dağılımı")
plt.show()

# %%
df_copy = df.copy()

# %% [markdown]
# ## MODEL

# %%
from sklearn.preprocessing import LabelEncoder,RobustScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, cross_validate, RandomizedSearchCV, validation_curve,cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

# %%
binary_cols = [col for col in df_copy.columns if df_copy[col].dtypes == "O" and df_copy[col].nunique() == 2]

def label_encoder(dataframe, binary_col):
    labelencoder = LabelEncoder()
    dataframe[binary_col] = labelencoder.fit_transform(dataframe[binary_col])
    return dataframe

for col in binary_cols:
    df_copy = label_encoder(df_copy, col)
    
# kategorik verileri sayısal değerlere dönüştürme yani label encoding işlemi

# %%
cat_cols = [col for col in df_copy if col not in binary_cols and col not in ["Carbon_Emission"]]

def one_hot_encoder(dataframe, categorical_cols, drop_first=True):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

ohe_cols = [col for col in df_copy.columns if 10 >= df_copy[col].nunique() > 2]

df_copy = one_hot_encoder(df_copy, ohe_cols, True)

# kategorik verileri ikili (binary) vektörlere dönüştürme yani one hot encoding işlemi

# %%
num_cols = df_copy.select_dtypes(include=['float64', 'int64']).columns

for col in num_cols:
    if col != "Carbon_Emission":
        transformer = StandardScaler().fit(df_copy[[col]])
        df_copy[col] = transformer.transform(df_copy[[col]])

# ortalama değerleri 0 ve standart sapmaları 1 olacak şekilde dönüştürme yani standartlaştırma işlemi

# %%
X = df_copy.drop(["Carbon_Emission","Recycling","Cooking_With"], axis=1)
y = df_copy["Carbon_Emission"]
# bağımlı ve bağımsız değişkenleri ayırma
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 17)
# veri setini test ve train seti olarak bölme

# %%
def plot_importance(model, features, num=len(X)):
    feature_imp = pd.DataFrame({'Değerler': model.feature_importances_, 'Özellikler': features.columns})
    plt.figure(figsize=(10, 8))
    sns.set(font_scale=1)
    sns.barplot(x="Değerler", y="Özellikler", data=feature_imp.sort_values(by="Değerler",
                                                                     ascending=False)[0:num])
    plt.title('Model bazında özelliklerin önem sırası')
    plt.tight_layout()
    plt.show()
    
# kurulan modele göre en önemli özellikleri sıralayan ve görselleştiren fonksiyon

# %%
models = [#('LR', LogisticRegression()),
          ('KNN', KNeighborsRegressor()),
          ('CART', DecisionTreeRegressor()),
          ('RF', RandomForestRegressor()),
          ('GBM', GradientBoostingRegressor()),
          ("XGBoost", XGBRegressor()),
          ("LightGBM", LGBMRegressor()),
          ("CatBoost", CatBoostRegressor(verbose=False))]
# model basarılarını kıyaslamak için birden çok modeli tanımlama

# %%
for name, regressor in models:
    rmse = np.mean(np.sqrt(-cross_val_score(regressor, X, y, cv=5, scoring="neg_mean_squared_error")))
    print(f"RMSE: {round(rmse, 4)} ({name}) ")
    
# modellerin rmse değerleri
# cross_val_score fonksiyonunu modelin ne kadar iyi çalıştığını RMSE değeri ve 5 katlı doğrulama ile 
# tespit etmek amacıyla kullandım
# Out:
# RMSE: 539.681 (KNN)
# RMSE: 482.3631 (CART)
# RMSE: 322.7425 (RF)
# RMSE: 251.6991 (GBM)
# RMSE: 203.4429 (XGBoost)
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001509 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 682
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 41
# [LightGBM] [Info] Start training from score 2278.372000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 682
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 41
# [LightGBM] [Info] Start training from score 2249.537000
# ...

# %% [markdown]
# #### R2 Başarı Metriği
# ##### R2, bağımsız değişkenlerin bağımlı değişkeni ne kadar iyi açıkladığını gösteren ölçüdür.
# ##### 0 ile 1 arasında değer alır. 1'e yaklaşan değerler, bağımsız değişkenlerin bağımlı değişkeni iyi açıkladığını gösterir.

# %% [markdown]
# ***

# %% [markdown]
# #### RMSE Başarı Metriği
# ##### RMSE, gerçek değerler ile modelin tahmin ettiği değerler arasındaki farkların karelerinin ortalamasının kareköküdür.
# ##### Daha düşük RMSE değeri, modelin tahminlerinin gerçek değerlere daha yakın olduğunu gösterir.

# %% [markdown]
# ***

# %% [markdown]
# ### En iyi RMSE değerini veren iki model
# #### RMSE: 186.9803 (LightGBM)
# #### RMSE: 153.0165 (CatBoost)

# %% [markdown]
# ### CATBOOST MODEL

# %%
catboost_model = CatBoostRegressor().fit(X_train, y_train) 
# ayırdığımız train setiyle eğittim
# Out:
# Learning rate set to 0.056868
# 0:	learn: 985.6191800	total: 5.13ms	remaining: 5.13s
# 1:	learn: 949.1611955	total: 11.2ms	remaining: 5.59s
# 2:	learn: 915.2188485	total: 16.7ms	remaining: 5.56s
# 3:	learn: 882.7873325	total: 21.8ms	remaining: 5.43s
# 4:	learn: 851.8051002	total: 27.9ms	remaining: 5.56s
# 5:	learn: 823.2676706	total: 33.6ms	remaining: 5.56s
# 6:	learn: 796.5898988	total: 38.8ms	remaining: 5.5s
# 7:	learn: 771.8270481	total: 44.2ms	remaining: 5.48s
# 8:	learn: 747.3114139	total: 49.1ms	remaining: 5.41s
# 9:	learn: 725.3182947	total: 54ms	remaining: 5.34s
# 10:	learn: 705.0704731	total: 58.9ms	remaining: 5.29s
# 11:	learn: 686.4162705	total: 63.9ms	remaining: 5.26s
# 12:	learn: 668.1222313	total: 68.8ms	remaining: 5.22s
# 13:	learn: 651.4338398	total: 73.8ms	remaining: 5.19s
# 14:	learn: 634.6755865	total: 78.6ms	remaining: 5.16s
# 15:	learn: 619.3039689	total: 83.7ms	remaining: 5.15s
# 16:	learn: 603.1351955	total: 88.6ms	remaining: 5.12s
# ...

# %% [markdown]
# ### TRAIN RMSE, R2

# %%
y_pred_catb = catboost_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred_catb)) 
# train setinin rmse değeri
# Out:
# 105.08088158088074

# %%
catboost_model.score(X_train, y_train) 
# train setinin r2 değeri
# Out:
# 0.989458661719186

# %% [markdown]
# ### TEST RMSE, R2

# %%
y_pred_catb = catboost_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred_catb))
# test setinin rmse değeri
# Out:
# 149.9467846306302

# %%
catboost_model.score(X_test, y_test)
# test setinin r2 değeri
# Out:
# 0.9772180612576452

# %%
plot_importance(catboost_model, X)
# catboost modelinin özellik önem sırası

# %% [markdown]
# ### LIGHTGBM MODEL

# %%
lightgbm_model = LGBMRegressor().fit(X_train, y_train)
# ayırdığımız train seti ile modeli eğittim
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 682
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 41
# [LightGBM] [Info] Start training from score 2275.839500

# %% [markdown]
# ### TRAIN RMSE, R2

# %%
y_pred_lgbm = lightgbm_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred_lgbm)) 
# train setine ait rmse değeri
# Out:
# 141.187975380458

# %%
lightgbm_model.score(X_train, y_train)  
# train setine ait r2 değeri
# Out:
# 0.9809697823138659

# %% [markdown]
# ### TEST RMSE, R2

# %%
y_pred_lgbm = lightgbm_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred_lgbm)) 
# test setine ait rmse değeri
# Out:
# 187.1604796355928

# %%
lightgbm_model.score(X_test, y_test) 
# test setine ait r2 değeri
# Out:
# 0.964506840244723

# %%
plot_importance(lightgbm_model, X)
# light gbm modeline göre özellik önem sırası

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_catb, color='#6D54B5', label='CatBoost Tahminleri ', marker='o',s=100,edgecolors="#b49cf6")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('CatBoost: Gerçek vs Tahmin (0.9772)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_lgbm, color='#4bc0b9', label='Light GBM Tahminleri', marker='o', s=100,edgecolors="#daffff")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('Light GBM: Gerçek vs Tahmin (0.9645)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# kurduğum iki modelin gerçek değerler arasındaki ilişkisi, scatter ile.

# %% [markdown]
# ### LIGHT GBM HIPERPARAMETRE OPTIMIZASYONU

# %% [markdown]
# Modeli daha iyi hale getirmek için doğru hiperparametreleri seçme sürecidir ve genellikle deneme-yanılma (trial-and-error) yöntemlerini içerir.

# %%
lightgbm_params =  {"learning_rate":[0.01,0.1],
                 'n_estimators': [100,300,500,1000],
                 "colsample_bytree":[1,0.5,0.7]}

# light gbm modeli üzerinde parametre optimizasyonunda deneyeceğim parametreleri tanımladım

# %%
lightgbm_best_grid = GridSearchCV(lightgbm_model,
                             lightgbm_params,
                             cv=5,
                              n_jobs=-1,
                             verbose=1).fit(X_train,y_train)

# grid search cv ile optimizasyon işlemini 5 katlı çapraz doğrulama olacak şekilde başlattım
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 682
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 41
# [LightGBM] [Info] Start training from score 2275.839500

# %%
lightgbm_best_grid.best_params_
# verdiğim parametreler arasında en iyi sonucu veren parametreler
# Out:
# {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'n_estimators': 500}

# %%
# {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'n_estimators': 500}

# %%
lgbm_final = lightgbm_model.set_params(**lightgbm_best_grid.best_params_).fit(X_train,y_train)
# bu parametreleri ilk modeldekilerle değiştirerek final modeli kurdum
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001548 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 682
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 41
# [LightGBM] [Info] Start training from score 2275.839500

# %% [markdown]
# ### TRAIN RMSE, R2

# %%
y_pred_lgbm_opt = lgbm_final.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred_lgbm_opt)) 
# final modelinin train setindeki rmse değeri
# Out:
# 76.25906772698043

# %%
lgbm_final.score(X_train, y_train)  
# final modelinin train setindeki r2 değeri
# Out:
# 0.9944482318826603

# %% [markdown]
# ### TEST RMSE, R2

# %%
y_pred_lgbm_opt = lgbm_final.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred_lgbm_opt)) 
# final modelinin test setindeki rmse değeri
# Out:
# 165.84354057887714

# %%
lgbm_final.score(X_test, y_test)  
# final modelinin test setindeki r2 değeri
# Out:
# 0.9721315068732503

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_lgbm, color='#3b9fff', label='Light GBM Tahminleri', marker='o',s=100,edgecolors="#9bceff")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('Light GBM:  Optimizasyonsuz (0.9645)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_lgbm_opt, color='#24ff2d', label='Light GBM Tahminleri', marker='o', s=100,edgecolors="#c9ffcb")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('Light GBM: Optimizasyonlu (0.9721)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# light gbmin ilk ve son halindeki başarının artışını görselleştirdim, scatter ile.

# %% [markdown]
# ### CART  MODEL
# #### RMSE: 482.3636 (CART)

# %%
cart_model =  DecisionTreeRegressor().fit(X_train,y_train)
# düşük başarı veren bir modeli train veri setiyle eğittim

# %% [markdown]
# ### TRAIN RMSE, R2

# %%
y_pred_cart_ = cart_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred_cart_)) 
# train veri setindeki rmse değeri
# Out:
# 0.0

# %%
cart_model.score(X_train, y_train)  
# train veri setindeki r2 değeri
# Out:
# 1.0

# %% [markdown]
# ### TEST RMSE, R2

# %%
y_pred_cart = cart_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred_cart)) 
# test veri setindeki rmse değeri
# Out:
# 472.9463827961897

# %%
cart_model.score(X_test, y_test)  
# test veri setindeki r2 değeri
# Out:
# 0.7733581109569947

# %%
plot_importance(cart_model, X)
# cart modeline ait özellik önem sırası

# %%
### CART modeli train yani eğitildiği veri setinde %100'lük bir tahmin başarısına sahipken,
### hiç görmediği veri setindeki tahmin başarısı yaklaşık olarak %78'dir.
### bu bize modelin eğitim setini öğrenmek yerine ezberlediğini gösterir.
### yani OVERFITTING durumu vardır.

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_train, y_pred_cart_, color='#b5004c', label='CART Train Tahminleri', marker='o',s=100,edgecolors="#ffb4d5")
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('CART Train: Gerçek vs Tahmin (1.0)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_cart, color='#ccb82b', label='CART Test Tahminleri', marker='o',s=100,edgecolors="#f6e675")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='--', linewidth=2, label='Doğru')
plt.title('CART Test: Gerçek vs Tahmin (0.7748)', fontsize=15)
plt.xlabel('Gerçek Değerler', fontsize=12)
plt.ylabel('Tahmin Edilen Değerler', fontsize=12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# OVERFITTING durumunu görselleştirdim, CART modelinin train ve testteki başarı durumları, scatter ile.

# %%
#### OVERFITTING'ı engellemenin yolları
# 	overfittingin basladıgı tespit edilen noktada (optimum nokta) model karmasıklıgını, 
# eğitim süresini, iterasyon süresini vs. durdurursak engellenebilir.
# 	veri seti boyutu arttırabiliriz.
# 	feature selection yapabiliriz yani veri setindeki gereksiz veya alakasız özellikleri çıkartabiliriz.
