# %% [markdown]
# #### Seçtiğiniz bir veri seti üzerinde veri analizi yapın.

# %% [markdown]
# #### Supermarket sales dataset
#
# Invoice id: Computer generated sales slip invoice identification number
#
# Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# City: Location of supercenters
#
# Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# Gender: Gender type of customer
#
# Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# Unit price: Price of each product in $
#
# Quantity: Number of products purchased by customer
#
# Tax: 5% tax fee for customer buying
#
# Total: Total price including tax
#
# Date: Date of purchase (Record available from January 2019 to March 2019)
#
# Time: Purchase time (10am to 9pm)
#
# Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# COGS: Cost of goods sold
#
# Gross margin percentage: Gross margin percentage
#
# Gross income: Gross income
#
# Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("supermarket_sales.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
def bilgi_al(df):
    print(df.shape)
    print("*****************")
    print(df.info())
    print("*****************")
    print(df.size)
    print("*****************")
    print(df.describe().T)
    print("*****************")
    print(df.isnull().any())
    print("*****************")
    print(df.head())
    print("*****************")
    print(df.tail())
    print("*****************")

# %%
bilgi_al(df)
# Out:
# (1000, 17)
# *****************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
plt.figure(figsize=(5, 4))
sns.countplot(df['Gender'])
plt.xlabel('Cinsiyet')
plt.ylabel('Adet')
plt.title(' Cinsiyete göre adet')
plt.show()
# Out:
# C:\Users\seyma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.Payment.unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
plt.figure(figsize=(5, 4))
sns.countplot(df['Payment'])
plt.xlabel('Ödeme türü')
plt.ylabel('Adet')
plt.title('Ödeme türleri ve kullanımları')
plt.show()
# Out:
# C:\Users\seyma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.Branch.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
plt.figure(figsize=(5, 4))
sns.countplot(df['Branch'])
plt.xlabel('Şubeler')
plt.ylabel('Adet')
plt.title('Şubelerin yoğunluğu')
plt.show()
# Out:
# C:\Users\seyma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["Customer type"].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
plt.figure(figsize=(5, 4))
sns.countplot(y ='City', hue = "Customer type", data = df) 
plt.xlabel('Adet')
plt.ylabel('Şehirler')
plt.show()

# %%
df["HOUR"] = df['Time'].apply(lambda x: int(x.split(':')[0]))

# %%
sns.lineplot(x="HOUR",  y ='Quantity',data =df).set_title("Saate göre satış")
plt.xlabel('Saat')
plt.ylabel('Miktarlar')
plt.show()

# %%
df["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df.groupby(["Product line"])[["Total"]].sum().reset_index()
# Out:
#              Product line       Total
# 0  Electronic accessories  54337.5315
# 1     Fashion accessories  54305.8950
# 2      Food and beverages  56144.8440
# 3       Health and beauty  49193.7390
# 4      Home and lifestyle  53861.9130
# 5       Sports and travel  55122.8265

# %%
df.groupby(["Branch","City"])[["Rating"]].mean().reset_index()
# Out:
#   Branch       City    Rating
# 0      A     Yangon  7.027059
# 1      B   Mandalay  6.818072
# 2      C  Naypyitaw  7.072866

# %%
df.groupby(["Payment"])[["Total"]].mean().reset_index()
# Out:
#        Payment       Total
# 0         Cash  326.181890
# 1  Credit card  324.009878
# 2      Ewallet  318.820600

# %%
df.groupby(["Product line"])[["Rating"]].mean().reset_index()
# Out:
#              Product line    Rating
# 0  Electronic accessories  6.924706
# 1     Fashion accessories  7.029213
# 2      Food and beverages  7.113218
# 3       Health and beauty  7.003289
# 4      Home and lifestyle  6.837500
# 5       Sports and travel  6.916265

# %%
df.groupby("Product line").agg({"Quantity":"sum",
                                "Rating":"mean"}).reset_index()
# Out:
#              Product line  Quantity    Rating
# 0  Electronic accessories       971  6.924706
# 1     Fashion accessories       902  7.029213
# 2      Food and beverages       952  7.113218
# 3       Health and beauty       854  7.003289
# 4      Home and lifestyle       911  6.837500
# 5       Sports and travel       920  6.916265

# %%
df.groupby("Product line").agg({"Tax 5%":"mean",
                                "Total":"sum",
                               "cogs":"sum",
                               "gross income": "sum"}).reset_index()
# Out:
#              Product line     Tax 5%       Total      cogs  gross income
# 0  Electronic accessories  15.220597  54337.5315  51750.03     2587.5015
# 1     Fashion accessories  14.528062  54305.8950  51719.90     2585.9950
# 2      Food and beverages  15.365310  56144.8440  53471.28     2673.5640
# 3       Health and beauty  15.411572  49193.7390  46851.18     2342.5590
# 4      Home and lifestyle  16.030331  53861.9130  51297.06     2564.8530
# 5       Sports and travel  15.812630  55122.8265  52497.93     2624.8965

# %%
df.groupby(["Branch","City"]).agg({"Total":"sum",
                               "cogs":"sum",
                               "gross income": "sum"}).reset_index()
# Out:
#   Branch       City        Total       cogs  gross income
# 0      A     Yangon  106200.3705  101143.21     5057.1605
# 1      B   Mandalay  106197.6720  101140.64     5057.0320
# 2      C  Naypyitaw  110568.7065  105303.53     5265.1765

# %%
df["MONTH"] = df['Date'].apply(lambda x: int(x.split('/')[0]))

# %%
df.groupby(["MONTH"])[["Total"]].sum().reset_index()
# Out:
#    MONTH       Total
# 0      1  116291.868
# 1      2   97219.374
# 2      3  109455.507

# %%
df.groupby(["MONTH"])[["Product line"]].count().reset_index()
# Out:
#    MONTH  Product line
# 0      1           352
# 1      2           303
# 2      3           345

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df[(df["Product line"] == "Home and lifestyle") & (df["Quantity"] > 7)]
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 7    315-22-5665      C  Naypyitaw        Normal  Female  Home and lifestyle
# 25   227-03-5010      A     Yangon        Member  Female  Home and lifestyle
# 39   777-82-7220      B   Mandalay        Member    Male  Home and lifestyle
# 58   817-48-8732      A     Yangon        Member  Female  Home and lifestyle
# 74   287-21-9091      A     Yangon        Normal    Male  Home and lifestyle
# 113  645-44-1170      A     Yangon        Member    Male  Home and lifestyle
# 114  237-01-6122      C  Naypyitaw        Member  Female  Home and lifestyle
# 123  336-78-2147      C  Naypyitaw        Member    Male  Home and lifestyle
# 148  262-47-2794      B   Mandalay        Member    Male  Home and lifestyle
# 166  234-65-2137      C  Naypyitaw        Normal    Male  Home and lifestyle
# 175  827-26-2100      A     Yangon        Member    Male  Home and lifestyle
# ...

# %%
df[(df["Payment"] == "Cash") & (df["Total"] > 500)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 14   829-34-3910      A     Yangon        Normal  Female
# 15   299-46-1805      B   Mandalay        Member  Female
# 31   149-71-6266      B   Mandalay        Member    Male
# 32   640-49-2076      B   Mandalay        Normal    Male
# 43   228-96-1411      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 959  384-59-6655      A     Yangon        Member  Female
# 972  452-04-8808      B   Mandalay        Normal    Male
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 14        Health and beauty       71.38        10  35.6900  749.4900
# 15        Sports and travel       93.72         6  28.1160  590.4360
# 31        Sports and travel       78.07         9  35.1315  737.7615
# ...

# %%
df[(df["Rating"] > 9.0)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 23   636-48-8204      A     Yangon        Normal    Male
# 28   145-94-9061      B   Mandalay        Normal  Female
# 45   132-32-9879      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 960  256-58-3609      C  Naypyitaw        Member    Male
# 961  324-92-3863      A     Yangon        Member    Male
# 967  195-06-0432      A     Yangon        Member    Male
# 968  605-03-2706      A     Yangon        Normal  Female
# 980  728-47-9078      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 23   Electronic accessories       34.56         5   8.6400  181.4400
# ...

# %%
df[(df["Rating"] < 5.0)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 10   351-62-0822      B   Mandalay        Member  Female
# 15   299-46-1805      B   Mandalay        Member  Female
# 16   656-95-9349      A     Yangon        Member  Female
# 19   319-50-3348      B   Mandalay        Normal  Female
# ..           ...    ...        ...           ...     ...
# 986  764-44-8999      B   Mandalay        Normal  Female
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 990  886-18-2897      A     Yangon        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 5    Electronic accessories       85.39         7  29.8865   627.6165
# 10      Fashion accessories       14.48         4   2.8960    60.8160
# ...

# %%
df[(df["Payment"] == "Credit card") | (df["Payment"] == "Ewallet")]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
df[(df["Gender"] == "Male") & (df["Product line"] == "Health and beauty") & (df["Rating"] > 7.0)]
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 3    123-19-1176      A     Yangon        Member   Male  Health and beauty
# 29   848-62-7243      A     Yangon        Normal   Male  Health and beauty
# 44   617-15-4209      C  Naypyitaw        Member   Male  Health and beauty
# 46   370-41-7321      B   Mandalay        Member   Male  Health and beauty
# 64   853-23-2453      B   Mandalay        Member   Male  Health and beauty
# 93   152-08-9985      B   Mandalay        Member   Male  Health and beauty
# 104  716-39-1409      B   Mandalay        Normal   Male  Health and beauty
# 141  280-17-4359      C  Naypyitaw        Member   Male  Health and beauty
# 179  342-65-4817      C  Naypyitaw        Member   Male  Health and beauty
# 198  699-01-4164      C  Naypyitaw        Normal   Male  Health and beauty
# 203  875-46-5808      B   Mandalay        Member   Male  Health and beauty
# ...
